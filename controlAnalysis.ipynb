# %%
import pandas as pd
import numpy as np
import pyreadr
import cmapPy.pandasGEXpress as pandasGEXpress
import cmapPy.pandasGEXpress.parse as cparse
#import cmapPy.pandasGEXpress.parse

from cmapPy.pandasGEXpress.write_gct import write
from cmapPy.pandasGEXpress import gctx2gct
from cmapPy.pandasGEXpress import*

# %%
siginfo = pd.read_csv("/home/ndjed/Programs/VSCode/LINCS_Project/siginfo_beta.txt", sep = '\t')
# Out:
# /tmp/ipykernel_26836/122777034.py:1: DtypeWarning: Columns (0,3,4,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   siginfo = pd.read_csv("/home/ndjed/Programs/VSCode/LINCS_Project/siginfo_beta.txt", sep = '\t')

# %%
control_data_3 = cparse.parse("/home/ndjed/Programs/VSCode/LINCS_Project/level3_beta_trt_cp_n1805898x12328.gctx")

# %%
control_data_3_ = cparse.parse("/home/ndjed/Programs/VSCode/LINCS_Project/level3_beta_ctl_n188708x12328.gctx")

# %%
compound_df_3 = control_data_3.data_df
control_df_3 = control_data_3_.data_df

# %%
control_data_4 = cparse.parse("/home/ndjed/Programs/VSCode/LINCS_Project/level4_beta_ctl_n188708x12328.gctx")
control_df_4 = control_data_4.data_df

# %%
control_data_5 = cparse.parse("/home/ndjed/Programs/VSCode/LINCS_Project/level5_beta_ctl_n58022x12328.gctx")
control_df_5 = control_data_5.data_df

# %%
misc_data_3 = cparse.parse("/data3/balaji/cmap/level3_beta_trt_misc_n26428x12328.gctx")
misc_df_3 = misc_data_3.data_df

# %%
compound_data_4 = cparse.parse("/home/ndjed/Programs/VSCode/LINCS_Project/level4_beta_trt_cp_n1805898x12328.gctx")

# %%
compound_df_4 = compound_data_4.data_df

# %%
compound_df_5 = cparse.parse("/data3/balaji/cmap/level5_beta_trt_cp_n720216x12328.gctx")
compound_df_5 = compound_df_5.data_df

# %%
instinfo = pd.read_csv("/data3/balaji/cmap/instinfo_beta.txt", sep = '\t')
# Out:
# /tmp/ipykernel_3588/95040671.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   instinfo = pd.read_csv("/data3/balaji/cmap/instinfo_beta.txt", sep = '\t')

# %%
instinfo
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 0              b11           NaN   20.00000             uL      20 uL
# 1              b10           NaN    1.00000             uL       1 uL
# 2              b12           NaN    0.10000          ng/ml  0.1 ng/ml
# 3              b12           NaN  150.00000             ng     150 ng
# 4             f3b5         6.660    5.33000             uM    6.66 uM
# ...            ...           ...        ...            ...        ...
# 3026455        b40         0.125    0.15625             uM   0.125 uM
# 3026456       f1b3         0.125    0.15625             uM   0.125 uM
# 3026457       f1b3         0.125    0.15625             uM   0.125 uM
# 3026458       f1b5         0.125    0.12350             uM   0.125 uM
# 3026459       f1b5         0.125    0.12350             uM   0.125 uM
#
#          pert_time pert_itime pert_time_unit cell_mfc_name     pert_mfc_id  \
# ...

# %%
pd.set_option('display.max_columns', 37)

# %%
compound_df_3
# Out:
# cid    ABY001_A375_XH_X1_B15:A13  ABY001_A375_XH_X1_B15:A14  \
# rid
# 10                       5.71910                    5.39460
# 100                      7.49240                    7.86690
# 1000                     6.56405                    7.67620
# 10000                    9.10520                    9.27270
# 10001                    7.45100                    8.61120
# ...                          ...                        ...
# 9990                     4.88970                    4.36270
# 9991                     5.55340                    5.82570
# 9992                     5.77130                    5.39940
# 9993                     6.16680                    5.90200
# 9997                     9.16890                    7.61165
#
# cid    ABY001_A375_XH_X1_B15:A15  ABY001_A375_XH_X1_B15:A16  \
# rid
# 10                        4.7285                    5.52900
# 100                       7.0399                    7.33550
# ...

# %%
control_df_3
# Out:
# cid    ABY001_A375_XH_X1_B15:A03  ABY001_A375_XH_X1_B15:A04  \
# rid
# 10                       4.90060                   5.546500
# 100                      5.38920                   6.141900
# 1000                     7.59470                   7.318299
# 10000                    9.29780                   8.282600
# 10001                    9.36170                   8.142300
# ...                          ...                        ...
# 9990                     3.73040                   4.522600
# 9991                     6.64510                   6.506500
# 9992                     5.50830                   5.367700
# 9993                     6.64185                   6.186900
# 9997                     7.66850                   8.741400
#
# cid    ABY001_A375_XH_X1_B15:A05  ABY001_A375_XH_X1_B15:A06  \
# rid
# 10                        5.7332                    5.42500
# 100                       8.0249                    6.07040
# ...

# %%
control_df_4
# Out:
# cid    ABY001_A375_XH_X1_B15:A03  ABY001_A375_XH_X1_B15:A04  \
# rid
# 10                       -0.7644                    -0.4047
# 100                      -0.3599                     2.2878
# 1000                     -0.7605                     0.1330
# 10000                     2.1027                    -0.0895
# 10001                    -0.9129                     0.5099
# ...                          ...                        ...
# 9990                      1.2768                     0.8472
# 9991                      0.1380                    -0.7726
# 9992                      0.3951                     0.9087
# 9993                     -0.1069                    -1.5469
# 9997                      0.9348                    -0.8366
#
# cid    ABY001_A375_XH_X1_B15:A05  ABY001_A375_XH_X1_B15:A06  \
# rid
# 10                       -0.0263                     0.0068
# 100                       0.6745                     0.4087
# ...

# %%
control_df_5
# Out:
# cid    ABY001_A375_XH:CMAP-000:-666:24  ABY001_A375_XH:CMAP-000:-666:3  \
# rid
# 10                            0.320485                       -0.475566
# 100                          -0.345218                       -0.188009
# 1000                          0.132398                       -0.097883
# 10000                         0.239660                       -0.194304
# 10001                        -0.205412                        0.026935
# ...                                ...                             ...
# 9990                          0.270770                        0.181627
# 9991                         -0.029380                       -0.268213
# 9992                          0.230479                        0.403226
# 9993                          0.181131                       -0.116034
# 9997                         -0.335440                        0.294594
#
# cid    ABY001_A375_XH:DMSO:-666:24  ABY001_A375_XH:DMSO:-666:3  \
# rid
# ...

# %%
siginfo[siginfo["sig_id"] == "ABY001_A375_XH:CMAP-000:-666:24"]
# Out:
#       bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 31567        b15           NaN        NaN            NaN        NaN
#
#       pert_itime  pert_time pert_time_unit cell_mfc_name pert_mfc_id  nsample  \
# 31567       24 h       24.0              h          A375    CMAP-000       15
#
#        cc_q75  ss_ngene       tas  pct_self_rank_q25  \
# 31567    0.12       303  0.192816            9.75936
#
#                                                       wt  \
# 31567  0.08,0.11,0.10,0.04,0.02,0.07,0.04,0.03,0.08,0...
#
#        median_recall_rank_spearman  median_recall_rank_wtcs_50  \
# 31567                      25.9358                     27.2727
#
#        median_recall_score_spearman  median_recall_score_wtcs_50  \
# 31567                      0.072612                     0.486932
#
#        batch_effect_tstat  batch_effect_tstat_pct  is_hiq  qc_pass   pert_id  \
# 31567               30.42                 92.2768       0        1  CMAP-000
#
# ...

# %%
sample_plate = siginfo[siginfo["det_plates"] == "ABY001_A375_XH_X1_B15" ]
sample_plate
# Out:
#       bead_batch  nearest_dose    pert_dose pert_dose_unit  pert_idose  \
# 2182         b15           NaN     5.000000          ug/ml     5 ug/ml
# 2297         b15         10.00    10.000000             uM       10 uM
# 2825         b15           NaN   937.500000             uM        1 uM
# 3055         b15          2.50     2.500000             uM      2.5 uM
# 3090         b15         10.00    10.000000             uM       10 uM
# ...          ...           ...          ...            ...         ...
# 71324        b15           NaN     0.015625          mg/ml  0.02 mg/ml
# 71578        b15          0.66     0.625000             uM     0.66 uM
# 73064        b15          0.66     0.625000             uM     0.66 uM
# 73854        b15         10.00    10.000000             uM       10 uM
# 75332        b15           NaN  1875.000000             uM     1.88 uM
#
#       pert_itime  pert_time pert_time_unit cell_mfc_name  \
# ...

# %%
sample_plate.groupby(["pert_type"]).mean()
# Out:
# /tmp/ipykernel_28177/979791852.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sample_plate.groupby(["pert_type"]).mean()
#              nearest_dose    pert_dose  pert_time    nsample    cc_q75  \
# pert_type
# ctl_untrt             NaN          NaN       13.5  14.000000  0.130000
# ctl_vehicle           NaN          NaN       13.5  13.500000  0.180000
# trt_aby               NaN  2465.080078       13.5   2.979167  0.162917
# trt_cp           4.386667     4.375000       13.5   2.950000  0.361000
#
#                ss_ngene       tas  pct_self_rank_q25  \
# pert_type
# ctl_untrt    290.500000  0.196152           8.622995
# ctl_vehicle  306.000000  0.237316           3.509360
# trt_aby      121.187500  0.135297          14.676638
# trt_cp       249.433333  0.301970           3.119431
#
# ...

# %%
sample_plate["pert_type"].value_counts()
# Out:
# trt_cp         60
# trt_aby        48
# ctl_untrt       2
# ctl_vehicle     2
# Name: pert_type, dtype: int64

# %%
misc_df_3["ABY001_A375_XH_X1_B15:P14"]
# Out:
# rid
# 10        5.41500
# 100       5.93370
# 1000     11.48610
# 10000     9.71540
# 10001     8.69380
#            ...
# 9990      4.68190
# 9991      5.81320
# 9992      5.55805
# 9993      5.45470
# 9997      8.02360
# Name: ABY001_A375_XH_X1_B15:P14, Length: 12328, dtype: float32

# %%
misc_df_3
# Out:
# cid    ABY001_A375_XH_X1_B15:C01  ABY001_A375_XH_X1_B15:C02  \
# rid
# 10                        3.7891                    4.59330
# 100                       7.6355                    6.38940
# 1000                      6.0380                    8.42030
# 10000                     9.9386                    9.25500
# 10001                     9.3145                    7.79710
# ...                          ...                        ...
# 9990                      4.1044                    4.03050
# 9991                      4.5929                    5.32775
# 9992                      5.8018                    5.38890
# 9993                      7.0878                    5.84460
# 9997                      6.1640                    7.48960
#
# cid    ABY001_A375_XH_X1_B15:C03  ABY001_A375_XH_X1_B15:C04  \
# rid
# 10                      5.230000                   5.678900
# 100                     6.874350                   8.283500
# ...

# %%
siginfo
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 0              b17           NaN      100.0          ug/ml  100 ug/ml
# 1              b15          10.0       10.0             uM      10 uM
# 2              b15           2.5        2.5             uM     2.5 uM
# 3              b18          10.0       10.0             uM      10 uM
# 4              b15          10.0       10.0             uM      10 uM
# ...            ...           ...        ...            ...        ...
# 1201939        b18          10.0       10.0             uM      10 uM
# 1201940        b18          10.0       10.0             uM      10 uM
# 1201941        b19          20.0       20.0             uM      20 uM
# 1201942        b19           4.0        5.0             uM       4 uM
# 1201943        b19          10.0       10.0             uM      10 uM
#
#         pert_itime  pert_time pert_time_unit cell_mfc_name    pert_mfc_id  \
# ...

# %%
sample_plate_2 = siginfo[siginfo["det_plates"] == "LTC002_HME1_3H_X1_B18" ]
sample_plate_2
# Out:
#       bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 3            b18       10.0000  10.000000             uM      10 uM
# 36           b18        0.2500   0.240000             uM    0.25 uM
# 37           b18        0.2200   0.220970             uM    0.22 uM
# 2301         b18        0.0020   0.001750             uM   0.002 uM
# 3770         b18        2.5000   2.500000             uM     2.5 uM
# ...          ...           ...        ...            ...        ...
# 72323        b18        0.0001   0.000208             uM  0.0001 uM
# 72344        b18        1.6700   1.767800             uM    1.67 uM
# 73856        b18        0.0030   0.002500             uM   0.003 uM
# 73857        b18        0.0001   0.000167             uM  0.0001 uM
# 75249        b18           NaN        NaN            NaN        NaN
#
#       pert_itime  pert_time pert_time_unit cell_mfc_name    pert_mfc_id  \
# 3            3 h        3.0              h          HME1  BRD-K81418486
# ...

# %%
sample_plate_2["pert_type"].value_counts()
# Out:
# trt_cp         116
# ctl_vehicle      1
# Name: pert_type, dtype: int64

# %%
sample_plate_2_control = sample_plate_2.loc[75249]

# %%
sample_plate_2_cp = sample_plate_2.iloc[0:116, :]

# %%
sample_plate_2_cp
# Out:
#       bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 3            b18       10.0000  10.000000             uM      10 uM
# 36           b18        0.2500   0.240000             uM    0.25 uM
# 37           b18        0.2200   0.220970             uM    0.22 uM
# 2301         b18        0.0020   0.001750             uM   0.002 uM
# 3770         b18        2.5000   2.500000             uM     2.5 uM
# ...          ...           ...        ...            ...        ...
# 71554        b18        0.1250   0.156250             uM   0.125 uM
# 72323        b18        0.0001   0.000208             uM  0.0001 uM
# 72344        b18        1.6700   1.767800             uM    1.67 uM
# 73856        b18        0.0030   0.002500             uM   0.003 uM
# 73857        b18        0.0001   0.000167             uM  0.0001 uM
#
#       pert_itime  pert_time pert_time_unit cell_mfc_name    pert_mfc_id  \
# 3            3 h        3.0              h          HME1  BRD-K81418486
# ...

# %%
sample_plate_2_cp_columns = compound_df_3.columns.str.contains("LTC002_HME1_3H_X1")
len(sample_plate_2_cp_columns)
# Out:
# 1805898

# %%
len(compound_df_3.columns[sample_plate_2_cp_columns])
# Out:
# 369

# %%
sample_plate_2_cp['nsample'].value_counts() #only 353
# Out:
# 1     93
# 11     5
# 6      5
# 21     5
# 16     4
# 2      2
# 3      1
# 15     1
# Name: nsample, dtype: int64

# %%
experiments_3 = compound_df_3[compound_df_3.columns[sample_plate_2_cp_columns]]

# %%
sample_plate_2_control
# Out:
# bead_batch                                                                    b18
# nearest_dose                                                                  NaN
# pert_dose                                                                     NaN
# pert_dose_unit                                                                NaN
# pert_idose                                                                    NaN
# pert_itime                                                                    3 h
# pert_time                                                                     3.0
# pert_time_unit                                                                  h
# cell_mfc_name                                                                HME1
# pert_mfc_id                                                                  DMSO
# nsample                                                                        10
# ...

# %%
sample_plate_2_ctrl_columns = control_df_3.columns.str.contains("LTC002_HME1_3H_X1")
len(control_df_3.columns[sample_plate_2_ctrl_columns])
# Out:
# 10

# %%
control_experiments_3 = control_df_3[control_df_3.columns[sample_plate_2_ctrl_columns]]

# %%
cp_ctrl_experiments_3 = pd.concat([experiments_3, control_experiments_3], axis = 1)

# %%
cp_ctrl_experiments_3
# Out:
# cid    LTC002_HME1_3H_X1_B18:A03  LTC002_HME1_3H_X1_B18:A04  \
# rid
# 10                        5.4592                     5.6928
# 100                       7.6250                     7.7623
# 1000                      5.1627                     6.8465
# 10000                     6.6355                     7.5023
# 10001                     9.3585                     9.4240
# ...                          ...                        ...
# 9990                      4.9184                     4.6477
# 9991                      7.2466                     7.0163
# 9992                      5.2766                     5.6135
# 9993                      7.9369                     7.5999
# 9997                      9.0672                     9.6730
#
# cid    LTC002_HME1_3H_X1_B18:A05  LTC002_HME1_3H_X1_B18:A06  \
# rid
# 10                       4.29600                    4.96050
# 100                      7.77560                    8.39470
# ...

# %%
def differentialExpression(df):
    mad_func = lambda x: np.median(np.abs(x - np.median(x)))

    mad_values = df.apply(mad_func, axis = 1)

    denom = 1.4826 * mad_values

    denom = list(denom)

    # for i in range(len(denom)):
    #     if denom[i] ==0:
    #         denom[i] = 0.1


    median_values = df.median(axis = "columns")

    numerator = df.subtract(median_values, axis = "index")

    next_result = numerator.divide(denom, axis = "index")

    return next_result

# %%
cp_ctrl_experiments_3_conversion = differentialExpression(cp_ctrl_experiments_3)

# %%
control_experiments_4 = control_df_4[control_df_4.columns[sample_plate_2_ctrl_columns]]

# %%
control_experiments_4
# Out:
# cid    LTC002_HME1_3H_X1_B18:A07  LTC002_HME1_3H_X1_B18:D18  \
# rid
# 10                        0.8563                    -0.8363
# 100                       1.1263                    -0.0132
# 1000                      0.5902                     0.3836
# 10000                     0.5731                    -1.9610
# 10001                     0.1818                    -1.0939
# ...                          ...                        ...
# 9990                     -0.2205                    -2.3793
# 9991                      0.1796                     0.9428
# 9992                      0.7353                    -1.7186
# 9993                     -0.0501                    -1.7912
# 9997                     -1.0039                     0.1747
#
# cid    LTC002_HME1_3H_X1_B18:E12  LTC002_HME1_3H_X1_B18:E24  \
# rid
# 10                        1.0738                    -0.6274
# 100                      -1.8316                     1.2874
# ...

# %%
compound_experiments_4 = compound_df_4[compound_df_4.columns[sample_plate_2_cp_columns]]

# %%
cp_ctrl_experiments_4 = pd.concat([compound_experiments_4, control_experiments_4], axis = 1)

# %%
cp_ctrl_experiments_3
# Out:
# cid    LTC002_HME1_3H_X1_B18:A03  LTC002_HME1_3H_X1_B18:A04  \
# rid
# 10                        5.4592                     5.6928
# 100                       7.6250                     7.7623
# 1000                      5.1627                     6.8465
# 10000                     6.6355                     7.5023
# 10001                     9.3585                     9.4240
# ...                          ...                        ...
# 9990                      4.9184                     4.6477
# 9991                      7.2466                     7.0163
# 9992                      5.2766                     5.6135
# 9993                      7.9369                     7.5999
# 9997                      9.0672                     9.6730
#
# cid    LTC002_HME1_3H_X1_B18:A05  LTC002_HME1_3H_X1_B18:A06  \
# rid
# 10                       4.29600                    4.96050
# 100                      7.77560                    8.39470
# ...

# %%
cp_ctrl_experiments_4
# Out:
# cid    LTC002_HME1_3H_X1_B18:A03  LTC002_HME1_3H_X1_B18:A04  \
# rid
# 10                       -0.3392                     0.8635
# 100                      -0.9421                    -0.5703
# 1000                     -2.1222                     0.1570
# 10000                    -1.5094                     0.1953
# 10001                     0.5070                     0.6940
# ...                          ...                        ...
# 9990                     -0.5422                    -0.0880
# 9991                     -0.4095                    -0.6007
# 9992                     -1.7576                     0.4402
# 9993                      0.3342                    -0.4689
# 9997                     -1.1159                     0.1778
#
# cid    LTC002_HME1_3H_X1_B18:A05  LTC002_HME1_3H_X1_B18:A06  \
# rid
# 10                       -2.7864                    -1.1274
# 100                      -0.7567                     0.4644
# ...

# %%
cp_ctrl_experiments_3_conversion
# Out:
# cid    LTC002_HME1_3H_X1_B18:A03  LTC002_HME1_3H_X1_B18:A04  \
# rid
# 10                      0.357396                   0.898472
# 100                    -0.751214                  -0.513424
# 1000                   -1.752205                   0.124377
# 10000                  -1.213850                   0.230440
# 10001                   0.529826                   0.679282
# ...                          ...                        ...
# 9990                    0.556008                  -0.254938
# 9991                   -0.168870                  -0.549034
# 9992                   -1.189638                   0.364111
# 9993                    0.644141                  -0.389060
# 9997                   -1.018641                   0.176813
#
# cid    LTC002_HME1_3H_X1_B18:A05  LTC002_HME1_3H_X1_B18:A06  \
# rid
# 10                     -2.336863                  -0.797717
# 100                    -0.490389                   0.581834
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(cp_ctrl_experiments_4.iloc[:,10], cp_ctrl_experiments_3_conversion.iloc[:,10])

# %%
import scipy.stats as stats
x = cp_ctrl_experiments_4.iloc[:,1]
y = cp_ctrl_experiments_3_conversion.iloc[:,1]

combine = pd.concat([x,y], axis = 1)
combine.replace([-np.inf, np.inf], np.nan, inplace=True)
combine.dropna(axis = 0, inplace = True)

x = combine.iloc[:,0]
y = combine.iloc[:, 1]

matrix = np.corrcoef(x,y) #ABY001_SUDHL4_XH_X1_B15
r, p = stats.pearsonr(x, y)

print(r)
# Out:
# 0.9802457099473609

# %%
corrList = []
anotherCorrList = []
for idx in range(len(cp_ctrl_experiments_3_conversion.columns)):
    x = cp_ctrl_experiments_3_conversion.iloc[idx,:]
    y = cp_ctrl_experiments_4.iloc[idx,:]

    combine = pd.concat([x,y], axis = 1)
    combine.replace([np.inf, -np.inf], np.nan, inplace=True)
    combine = combine.dropna(axis = 0)
    x= combine.iloc[:,0]
    y = combine.iloc[:,1]

    print(x)
    print(y)
    
    matrix = np.corrcoef(x,y) #ABY001_SUDHL4_XH_X1_B15
    corrList.append(matrix[0][1])
    r, p = stats.pearsonr(x, y)
    anotherCorrList.append(r)
# Out:
# cid
# LTC002_HME1_3H_X1_B18:A03    0.357396
# LTC002_HME1_3H_X1_B18:A04    0.898472
# LTC002_HME1_3H_X1_B18:A05   -2.336863
# LTC002_HME1_3H_X1_B18:A06   -0.797717
# LTC002_HME1_3H_X1_B18:A08   -1.295015
#                                ...
# LTC002_HME1_3H_X1_B18:J19   -0.150208
# LTC002_HME1_3H_X1_B18:K12   -1.201206
# LTC002_HME1_3H_X1_B18:O19   -0.775017
# LTC002_HME1_3H_X1_B18:P01   -0.656425
# LTC002_HME1_3H_X1_B18:P07    0.812308
# Name: 10, Length: 379, dtype: float64
# cid
# LTC002_HME1_3H_X1_B18:A03   -0.3392
# LTC002_HME1_3H_X1_B18:A04    0.8635
# LTC002_HME1_3H_X1_B18:A05   -2.7864
# LTC002_HME1_3H_X1_B18:A06   -1.1274
# LTC002_HME1_3H_X1_B18:A08   -1.9175
#                               ...
# LTC002_HME1_3H_X1_B18:J19    0.2302
# LTC002_HME1_3H_X1_B18:K12    0.2364
# LTC002_HME1_3H_X1_B18:O19   -0.5653
# LTC002_HME1_3H_X1_B18:P01   -0.3394
# LTC002_HME1_3H_X1_B18:P07   -0.2218
# Name: 10, Length: 379, dtype: float32
# cid
# LTC002_HME1_3H_X1_B18:A03   -0.751214
# ...

# %%
anotherCorrList.sort()

# %%
anotherCorrList
# Out:
# [0.28738132444522224,
#  0.3933679835957301,
#  0.46821188181559525,
#  0.500827239512316,
#  0.5467218752162186,
#  0.5911590006421067,
#  0.5974890905531884,
#  0.6047949985404002,
#  0.6288597565474492,
#  0.6315269204506697,
#  0.6667203713197669,
#  0.6716106741266965,
#  0.6735673019289455,
#  0.6861008619727793,
#  0.6902413162313273,
#  0.6907130110321944,
#  0.6923658061041639,
#  0.6952255577196262,
#  0.7122290787139189,
#  0.7159034760628264,
#  0.7176800358646775,
#  0.7352331354796691,
#  0.7395331121796784,
#  0.7400041532439405,
#  0.7439616285016317,
#  0.7554967999037612,
#  0.7595417533502661,
#  0.7617603625760321,
#  0.7687216485263917,
#  0.773721028713058,
#  0.7826194528826564,
#  0.7853766663163998,
#  0.7861116756969583,
#  0.787086000163729,
#  0.7898149769343092,
#  0.7902009301387614,
#  0.8008936705674138,
#  0.804314274883051,
#  0.8057040780087457,
#  0.8059373786790458,
#  0.8060619163586655,
#  0.8068374377325147,
#  0.8088651142992787,
# ...

# %%
x.value_counts()
# Out:
#  0.0000    75
#  0.6745    31
# -0.6745    22
#  0.1362     5
#  0.7925     5
#            ..
# -1.6625     1
# -1.4413     1
# -1.6910     1
#  0.1728     1
# -0.6007     1
# Name: LTC002_HME1_3H_X1_B18:A04, Length: 10261, dtype: int64

# %%
y.value_counts()
# Out:
#  0.000000    39
# -inf          4
# -0.674491     2
# -0.712714     2
#  inf          2
#              ..
# -1.661206     1
# -0.439950     1
#  0.281719     1
#  1.733379     1
#  0.176813     1
# Name: LTC002_HME1_3H_X1_B18:A04, Length: 12255, dtype: int64

# %%
sample_siginfo = siginfo.query('cmap_name == "capecitabine" | cmap_name == "doxorubicin" | cmap_name == "epirubicin" | cmap_name == "paclitaxel" | cmap_name == "docetaxel"  ')

# %%
def write_dataframe_to_csv(dataframe, filename):
    import csv

    dataframe.to_csv(filename, index=False)

# %%
write_dataframe_to_csv(sample_siginfo, "BRCA_sample_siginfo")

# %%
first_metadata = siginfo[siginfo['cmap_name'] == 'doxorubicin']

# %%
sample_siginfo_sig_id = sample_siginfo['sig_id'].tolist()
brca_compound_data_5 = compound_df_5[compound_df_5.columns[compound_df_5.columns.isin(sample_siginfo_sig_id)]]

# %%
brca_compound_data_5
# Out:
# cid    ASG002_22RV1_24H:G01  ASG002_22RV1_24H:G02  ASG002_22RV1_24H:G03  \
# rid
# 10                   6.3341                5.2243                1.4654
# 100                  5.7040                3.8875                1.5365
# 1000                -2.9910               -1.9209               -1.0358
# 10000                3.9700                5.6208                0.5289
# 10001               -2.3277               -2.3518                0.2349
# ...                     ...                   ...                   ...
# 9990                 4.2057                3.6518                1.9640
# 9991                 1.6694               -0.2801               -1.4899
# 9992                 6.7483                5.7797                1.7852
# 9993                 3.6206                3.9382                0.8368
# 9997                 2.1597               -2.6141                0.5818
#
# cid    ASG002_A204_24H:G01  ASG002_A204_24H:G02  ASG002_A204_24H:G03  \
# rid
# ...

# %%
write_dataframe_to_csv(brca_compound_data_5, "BRCA_COMPOUND_5_DATA_5_DRUGS")

# %%
first_cp = pd.DataFrame(compound_df_5["HOG002_A549_6H:BRD-K92093830-003-18-3:1.11"])
for i in first_metadata['sig_id']:
    temp = pd.DataFrame(compound_df_5[i])
    first_cp = pd.concat([first_cp, temp], axis = 1)

# %%
# first_cp = first_cp.drop(first_cp.columns[0], axis = 1)

# %%
# del first_cp[first_cp.columns[0]]

# %%
first_cp = first_cp.iloc[:, 1:]

# %%
first_cp
# Out:
#        HOG002_A549_6H:BRD-K92093830-003-18-3:1.11  \
# 0                                        1.151536
# 1                                        0.365283
# 2                                       -0.936901
# 3                                       -0.133124
# 4                                        0.416201
# ...                                           ...
# 12323                                    0.712022
# 12324                                   -1.135878
# 12325                                    0.335211
# 12326                                    0.289232
# 12327                                   -0.130264
#
#        HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.1234  \
# 0                                          -0.440742
# 1                                          -0.089785
# 2                                          -0.402407
# 3                                           0.616265
# 4                                          -0.668459
# ...

# %%
write_dataframe_to_csv(first_cp, "doxorubicin_level_5_cp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 write_dataframe_to_csv(first_cp, "doxorubicin_level_5_cp")
#
# NameError: name 'write_dataframe_to_csv' is not defined

# %%
first_cp = pd.read_csv("/home/ndjed/Programs/VSCode/LINCS_Project/doxorubicin_level_5_cp")

# %%
first_cp
# Out:
#        HOG002_A549_6H:BRD-K92093830-003-18-3:1.11  \
# 0                                        1.151536
# 1                                        0.365283
# 2                                       -0.936901
# 3                                       -0.133124
# 4                                        0.416201
# ...                                           ...
# 12323                                    0.712022
# 12324                                   -1.135878
# 12325                                    0.335211
# 12326                                    0.289232
# 12327                                   -0.130264
#
#        HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.1234  \
# 0                                          -0.440742
# 1                                          -0.089785
# 2                                          -0.402407
# 3                                           0.616265
# 4                                          -0.668459
# ...

# %%
first_cp_mc57 = first_cp[(first_cp.columns[first_cp.columns.str.contains("MCF7")])]
first_cp_mc57
# Out:
#        HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.1234  \
# 0                                          -0.440742
# 1                                          -0.089785
# 2                                          -0.402407
# 3                                           0.616265
# 4                                          -0.668459
# ...                                              ...
# 12323                                       0.701270
# 12324                                       0.515685
# 12325                                      -0.161944
# 12326                                       0.350343
# 12327                                       0.678995
#
#        HOG002_MCF7_6H:BRD-K92093830-003-18-3:0.3704  \
# 0                                          0.519634
# 1                                         -0.009424
# 2                                          0.967200
# 3                                         -1.291086
# 4                                          0.890896
# ...

# %%
control_df_5[control_df_5.columns[control_df_5.columns.str.contains("MCF7")]]
# Out:
# cid    ASG001_MCF7_24H:B13  ASG001_MCF7_24H:C01  ASG001_MCF7_24H:C13  \
# rid
# 10                  0.1015              -0.4409              -0.0335
# 100                 0.3263               0.6368               0.7590
# 1000                1.0224               0.2030               4.1878
# 10000              -0.2279              -0.3544              -3.2059
# 10001              -0.3206              -0.2472              -0.4720
# ...                    ...                  ...                  ...
# 9990                0.0141               1.6248              -2.1682
# 9991                0.8926               0.3428               1.6520
# 9992                0.0737              -0.5018               1.2258
# 9993                1.3543              -0.9607              -1.1071
# 9997                0.3156              -0.6542              -0.7851
#
# cid    ASG001_MCF7_24H:D01  ASG001_MCF7_24H:D13  ASG001_MCF7_24H:DMSO:0.1  \
# rid
# ...

# %%
first_cp.iloc[0,:]
# Out:
# HOG002_A549_6H:BRD-K92093830-003-18-3:1.11       1.151536
# HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.1234   -0.440742
# HOG002_MCF7_6H:BRD-K92093830-003-18-3:0.3704     0.519634
# HOG002_A549_24H:BRD-K92093830-003-18-3:0.0412    0.225833
# LCP001_MCF10A.KRAS.HG_24H:D09                    2.152653
#                                                    ...
# PBIOA018_PC3_24H:O11                             0.239275
# PBIOA018_A375_24H:O11                            1.878993
# PBIOA018_A375_24H:O08                            2.899254
# PBIOA018_HCC515_24H:O09                          0.661577
# PBIOA018_PC3_24H:O07                             5.521400
# Name: 0, Length: 665, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.xlabel("Level_5_MC57_doxorubicin_gene")
plt.ylabel("frequency")
plt.hist(first_cp.iloc[0,:])
# Out:
# (array([ 12., 114., 177., 156.,  86.,  59.,  34.,   8.,  11.,   8.]),
#  array([-2.2777884 , -1.37067446, -0.46356052,  0.44355342,  1.35066736,
#          2.2577813 ,  3.16489524,  4.07200918,  4.97912312,  5.88623706,
#          6.793351  ]),
#  <BarContainer object of 10 artists>)

# %%
# need to map to gene symbol
gene_names = pd.read_csv("/data3/balaji/cmap/geneinfo_beta.txt", sep = '\t')

# %%
control_df_5.index
# Out:
# Index(['10', '100', '1000', '10000', '10001', '10003', '10004', '10005',
#        '10006', '10007',
#        ...
#        '9985', '9987', '9988', '9989', '999', '9990', '9991', '9992', '9993',
#        '9997'],
#       dtype='object', name='rid', length=12328)

# %%
def dictCreation(key, value):
    idToSymbol = zip(key, value) # zip creates a dictionary between gene id and the gene symbol
    idToSymbol = list(idToSymbol)
    idToSymbol = dict(idToSymbol)

    return idToSymbol

def iteratingThroughDict(key, dictionary):

    map_list = []
    key  = list(map(int, key)) # fastest way to convert string to integer
    for i in key: # the column with entrez id in raw_gene_exp file
        for key in dictionary:
            if i == key:
                map_list.append(dictionary[key])


    return map_list

# %%
gene_dict = dictCreation(gene_names.gene_id, gene_names.gene_symbol)

# %%
first_cp.index = compound_df_5.index

# %%
update_gene_index = iteratingThroughDict(first_cp.index, gene_dict)

# %%
first_cp.index = update_gene_index

# %%
write_dataframe_to_csv(first_cp, "doxorubicin_level_5_cp")

# %%
first_cp
# Out:
#          HOG002_A549_6H:BRD-K92093830-003-18-3:1.11  \
# NAT2                                       1.151536
# ADA                                        0.365283
# CDH2                                      -0.936901
# AKT3                                      -0.133124
# MED6                                       0.416201
# ...                                             ...
# SLC12A6                                    0.712022
# PTBP3                                     -1.135878
# KCNE2                                      0.335211
# DGCR2                                      0.289232
# SCO2                                      -0.130264
#
#          HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.1234  \
# NAT2                                         -0.440742
# ADA                                          -0.089785
# CDH2                                         -0.402407
# AKT3                                          0.616265
# MED6                                         -0.668459
# ...

# %%
compound_df_5.index[:15]
# Out:
# Index(['10', '100', '1000', '10000', '10001', '10003', '10004', '10005',
#        '10006', '10007', '10009', '100093698', '1001', '10010', '100126791'],
#       dtype='object', name='rid')

# %%
pd.options.display.max_columns = 37

# %%
BRCA_sample_siginfo = pd.read_csv("/home/ndjed/Programs/VSCode/LINCS_Project/BRCA_sample_siginfo")

# %%
BRCA_sample_siginfo_dox = BRCA_sample_siginfo[BRCA_sample_siginfo['cmap_name'] == "doxorubicin"]

# %%
BRCA_sample_siginfo_dox
# Out:
#      bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose pert_itime  \
# 0         f1b10         1.110   1.110000             uM    1.11 uM        6 h
# 2           b10         0.125   0.123400             uM   0.125 uM       24 h
# 4         f1b10         0.370   0.370400             uM    0.37 uM        6 h
# 7         f1b10         0.040   0.041200             uM    0.04 uM       24 h
# 11          b33         1.110   1.111110             uM    1.11 uM       24 h
# ...         ...           ...        ...            ...        ...        ...
# 2141        b21         0.125   0.123457             uM   0.125 uM       24 h
# 2143        b21         0.125   0.123457             uM   0.125 uM       24 h
# 2145        b21         3.330   3.333330             uM    3.33 uM       24 h
# 2147        b21         1.110   1.111110             uM    1.11 uM       24 h
# 2148        b21        10.000  10.000000             uM      10 uM       24 h
#
# ...

# %%
BRCA_sample_siginfo_dox.index
# Out:
# Int64Index([   0,    2,    4,    7,   11,   13,   16,   24,   25,   32,
#             ...
#             2133, 2134, 2135, 2138, 2139, 2141, 2143, 2145, 2147, 2148],
#            dtype='int64', length=665)

# %%
BRCA_sample_siginfo_dox.loc[0, "det_plates"]
# Out:
# 'HOG002_A549_6H_X1_F1B10|HOG002_A549_6H_X2_F1B10|HOG002_A549_6H_X3_F1B10'

# %%
weird_det_plate = siginfo[siginfo["det_plates"] == "HOG002_A549_6H_X1_F1B10|HOG002_A549_6H_X2_F1B10|HOG002_A549_6H_X3_F1B10"]

weird_det_plate[weird_det_plate["cmap_name"] == "doxorubicin"]
# Out:
#       bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 169        f1b10         1.110     1.1100             uM    1.11 uM
# 4728       f1b10         3.330     3.3300             uM    3.33 uM
# 11429      f1b10         0.125     0.1234             uM   0.125 uM
# 15300      f1b10         0.370     0.3704             uM    0.37 uM
# 18450      f1b10         0.010     0.0130             uM    0.01 uM
# 41734      f1b10         0.040     0.0412             uM    0.04 uM
# 44054      f1b10        10.000    10.0000             uM      10 uM
# 63425      f1b10         0.004     0.0045             uM   0.004 uM
#
#       pert_itime  pert_time pert_time_unit cell_mfc_name    pert_mfc_id  \
# 169          6 h        6.0              h          A549  BRD-K92093830
# 4728         6 h        6.0              h          A549  BRD-K92093830
# 11429        6 h        6.0              h          A549  BRD-K92093830
# ...

# %%
weird_det_plate['cmap_name'].value_counts()
# Out:
# DMSO              10
# mitoxantrone       9
# teniposide         9
# DL-PDMP            9
# gemcitabine        9
# BMS-536924         9
# vorinostat         9
# geldanamycin       9
# importazole        9
# NVP-BEZ235         9
# BRD-K28296557      9
# niclosamide        9
# tretinoin          9
# phenanthridone     9
# SKI-II             9
# NVP-AUY922         9
# COT-10b            9
# BRD-K68202742      9
# phloretin          9
# AG-14361           9
# BRD-K76674262      9
# withaferin-a       9
# BRD-K05649647      9
# estradiol          8
# sirolimus          8
# LY-294002          8
# XAV-939            8
# daunorubicin       8
# wortmannin         8
# tanespimycin       8
# CD-437             8
# SID-26681509       8
# doxorubicin        8
# Name: cmap_name, dtype: int64

# %%
weird_det_plate[weird_det_plate['pert_type'] == 'ctl_vehicle']
# Out:
#       bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 2929       f1b10           NaN        NaN            NaN        NaN
# 9779       f1b10           NaN        NaN            NaN        NaN
# 11270      f1b10           NaN        NaN            NaN        NaN
# 28701      f1b10           NaN        NaN            NaN        NaN
# 36264      f1b10           NaN        NaN            NaN        NaN
# 41512      f1b10           NaN        NaN            NaN        NaN
# 43078      f1b10           NaN        NaN            NaN        NaN
# 46719      f1b10           NaN        NaN            NaN        NaN
# 57979      f1b10           NaN        NaN            NaN        NaN
# 64639      f1b10           NaN        NaN            NaN        NaN
#
#       pert_itime  pert_time pert_time_unit cell_mfc_name pert_mfc_id  nsample  \
# 2929         6 h        6.0              h          A549        DMSO        3
# ...

# %%
weird_det_plate['cell_mfc_name'].value_counts()
# Out:
# A549    288
# Name: cell_mfc_name, dtype: int64

# %%
control_df_5["HOG002_A549_6H:N13"]
# Out:
# rid
# 10      -1.3872
# 100      1.1391
# 1000    -0.6327
# 10000   -0.3395
# 10001    0.1224
#           ...
# 9990     0.0006
# 9991     0.2661
# 9992    -0.6471
# 9993     0.4019
# 9997     0.0383
# Name: HOG002_A549_6H:N13, Length: 12328, dtype: float32

# %%
x =  first_cp["HOG002_A549_6H:BRD-K92093830-003-18-3:1.11"]

# %%
y = first_cp["HOG002_A549_6H:BRD-K92093830-003-18-3:3.33"] # y has the higher dosage

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 first_metadata
#
# NameError: name 'first_metadata' is not defined

# %%
import matplotlib.pyplot as plt
from scipy import stats

r, p = stats.pearsonr(x, y)
print(r)
plt.scatter(x,y)
# Out:
# 0.5238305852575063

# %%
plt.hist(x)
plt.xlabel("HOG002_A549_6H:BRD-K92093830-003-18-3:1.11")
# Out:
# Text(0.5, 0, 'HOG002_A549_6H:BRD-K92093830-003-18-3:1.11')

# %%
plt.hist(y)
plt.xlabel("HOG002_A549_6H:BRD-K92093830-003-18-3:3.33")
# Out:
# Text(0.5, 0, 'HOG002_A549_6H:BRD-K92093830-003-18-3:3.33')

# %%
weird_det_plate[weird_det_plate['pert_type'] == 'ctl_vehicle'] # controls for all experiments with these specific det plates
# Out:
#       bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 2929       f1b10           NaN        NaN            NaN        NaN
# 9779       f1b10           NaN        NaN            NaN        NaN
# 11270      f1b10           NaN        NaN            NaN        NaN
# 28701      f1b10           NaN        NaN            NaN        NaN
# 36264      f1b10           NaN        NaN            NaN        NaN
# 41512      f1b10           NaN        NaN            NaN        NaN
# 43078      f1b10           NaN        NaN            NaN        NaN
# 46719      f1b10           NaN        NaN            NaN        NaN
# 57979      f1b10           NaN        NaN            NaN        NaN
# 64639      f1b10           NaN        NaN            NaN        NaN
#
#       pert_itime  pert_time pert_time_unit cell_mfc_name pert_mfc_id  nsample  \
# 2929         6 h        6.0              h          A549        DMSO        3
# ...

# %%
plt.hist(first_cp["HOG002_A549_6H:BRD-K92093830-003-18-3:0.1234"])
plt.xlabel("HOG002_A549_6H:BRD-K92093830-003-18-3:0.1234")
# Out:
# Text(0.5, 0, 'HOG002_A549_6H:BRD-K92093830-003-18-3:0.1234')

# %%
plt.hist(control_df_5["HOG002_A549_6H:D01"])
plt.xlabel("HOG002_A549_6H:D01")
# Out:
# Text(0.5, 0, 'HOG002_A549_6H:D01')

# %%
# which control should I use to subtract from?, average them?

# %%
ergo_plate_test = instinfo[instinfo["rna_plate"] == "ERG013_VCAP_72H_X3"]

# %%
ergo_plate_test['pert_type'].value_counts()
# Out:
# trt_sh        87
# ctl_vector    32
# ctl_untrt     15
# Name: pert_type, dtype: int64

# %%
weird_det_plate_control = weird_det_plate[weird_det_plate['pert_type'] == 'ctl_vehicle']

# %%
weird_det_plate_cp = weird_det_plate[weird_det_plate['pert_type'] == 'trt_cp']
weird_det_plate_cp
# Out:
#       bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 169        f1b10         1.110     1.1100             uM    1.11 uM
# 893        f1b10         0.010     0.0130             uM    0.01 uM
# 894        f1b10         1.250     1.2333             uM    1.25 uM
# 954        f1b10         0.125     0.1370             uM   0.125 uM
# 1680       f1b10         0.004     0.0045             uM   0.004 uM
# ...          ...           ...        ...            ...        ...
# 74008      f1b10         0.370     0.4111             uM    0.37 uM
# 74009      f1b10         0.370     0.3704             uM    0.37 uM
# 74734      f1b10         0.004     0.0045             uM   0.004 uM
# 74798      f1b10         3.330     3.3300             uM    3.33 uM
# 74799      f1b10         1.110     1.1100             uM    1.11 uM
#
#       pert_itime  pert_time pert_time_unit cell_mfc_name    pert_mfc_id  \
# 169          6 h        6.0              h          A549  BRD-K92093830
# ...

# %%
sig_id_list = []
for i in weird_det_plate_cp['sig_id']:
    sig_id_list.append(i)

# %%
first_cp[first_cp.columns[first_cp.columns.str.contains("A549")]]
# Out:
#          HOG002_A549_6H:BRD-K92093830-003-18-3:1.11  \
# NAT2                                       1.151536
# ADA                                        0.365283
# CDH2                                      -0.936901
# AKT3                                      -0.133124
# MED6                                       0.416201
# ...                                             ...
# SLC12A6                                    0.712022
# PTBP3                                     -1.135878
# KCNE2                                      0.335211
# DGCR2                                      0.289232
# SCO2                                      -0.130264
#
#          HOG002_A549_24H:BRD-K92093830-003-18-3:0.0412  \
# NAT2                                          0.225833
# ADA                                           0.253766
# CDH2                                          0.800351
# AKT3                                          0.198098
# MED6                                          0.294463
# ...

# %%
a = first_cp[first_cp.columns[first_cp.columns.str.contains("A549")]].mean(axis = 1)

# %%
a.hist()
# Out:
# <Axes: >

# %%
first_cp['HOG002_A549_6H:BRD-K11163873-001-02-8:0.013']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Programs/anaconda3/envs/cmapPy3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/Programs/anaconda3/envs/cmapPy3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Programs/anaconda3/envs/cmapPy3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HOG002_A549_6H:BRD-K11163873-001-02-8:0.013'
#
# ...

# %%
cp_3_a549 = first_cp[['HOG002_A549_6H:BRD-K92093830-003-18-3:1.11',
 'HOG002_A549_6H:BRD-K11163873-001-02-8:0.013',
 'HOG002_A549_6H:BRD-K18190982-002-01-2:1.2333',
 'HOG002_A549_6H:BRD-K12762134-001-01-3:0.137',
 'HOG002_A549_6H:BRD-K05649647-001-03-7:0.0045',
 'HOG002_A549_6H:BRD-K88378636-001-02-8:10',
 'HOG002_A549_6H:BRD-A75409952-001-01-6:0.3704',
 'HOG002_A549_6H:BRD-K00615600-001-06-1:3.33',
 'HOG002_A549_6H:BRD-K15563106-001-08-1:0.3704',
 'HOG002_A549_6H:BRD-K88378636-001-02-8:0.0015',
 'HOG002_A549_6H:BRD-K68202742-001-10-8:0.1235',
 'HOG002_A549_6H:BRD-K28907958-001-02-7:0.0457',
 'HOG002_A549_6H:BRD-K18190982-002-01-2:3.7',
 'HOG002_A549_6H:BRD-K08417745-001-02-9:10',
 'HOG002_A549_6H:BRD-K76674262-001-02-5:0.3704',
 'HOG002_A549_6H:BRD-K41859756-001-01-9:0.0412',
 'HOG002_A549_6H:BRD-K00615600-001-06-1:1.11',
 'HOG002_A549_6H:BRD-A35588707-001-04-8:0.013',
 'HOG002_A549_6H:BRD-A35588707-001-04-8:0.0015',
 'HOG002_A549_6H:BRD-K21680192-300-10-2:3.33',
 'HOG002_A549_6H:BRD-K92093830-003-18-3:3.33',
 'HOG002_A549_6H:BRD-K76674262-001-02-5:0.0412',
 'HOG002_A549_6H:BRD-K21680192-300-10-2:0.3704',
 'HOG002_A549_6H:BRD-K12762134-001-01-3:11.1',
 'HOG002_A549_6H:BRD-K71879491-001-22-6:0.0015']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 cp_3_a549 = first_cp[['HOG002_A549_6H:BRD-K92093830-003-18-3:1.11',
#       2  'HOG002_A549_6H:BRD-K11163873-001-02-8:0.013',
#       3  'HOG002_A549_6H:BRD-K18190982-002-01-2:1.2333',
#       4  'HOG002_A549_6H:BRD-K12762134-001-01-3:0.137',
#       5  'HOG002_A549_6H:BRD-K05649647-001-03-7:0.0045',
#       6  'HOG002_A549_6H:BRD-K88378636-001-02-8:10',
#       7  'HOG002_A549_6H:BRD-A75409952-001-01-6:0.3704',
#       8  'HOG002_A549_6H:BRD-K00615600-001-06-1:3.33',
#       9  'HOG002_A549_6H:BRD-K15563106-001-08-1:0.3704',
#      10  'HOG002_A549_6H:BRD-K88378636-001-02-8:0.0015',
#      11  'HOG002_A549_6H:BRD-K68202742-001-10-8:0.1235',
#      12  'HOG002_A549_6H:BRD-K28907958-001-02-7:0.0457',
#      13  'HOG002_A549_6H:BRD-K18190982-002-01-2:3.7',
# ...

# %%
control_3_a549 = control_df_5[["HOG002_A549_6H:C01", "HOG002_A549_6H:I24", "HOG002_A549_6H:P01", "HOG002_A549_6H:D01", "HOG002_A549_6H:DMSO:0.1","HOG002_A549_6H:N01", "HOG002_A549_6H:O01", "HOG002_A549_6H:I01", "HOG002_A549_6H:E23", "HOG002_A549_6H:L01"]]

# %%
control_3_a549['avg_control_values'] = control_3_a549.mean(axis = 1)
# Out:
# /tmp/ipykernel_3588/2239201115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_3_a549['avg_control_values'] = control_3_a549.mean(axis = 1)

# %%
print([control_3_a549.mean(axis=1), control_3_a549.std(axis=1)])
print(first_cp[first_cp.columns[first_cp.columns.str.contains("A549")]])
# Out:
# [rid
# 10       0.588721
# 100     -0.230470
# 1000    -0.077285
# 10000    0.232324
# 10001   -0.066576
#            ...
# 9990    -0.478377
# 9991     0.117109
# 9992    -0.086060
# 9993    -0.017983
# 9997    -0.348189
# Length: 12328, dtype: float32, rid
# 10       0.714678
# 100      0.288984
# 1000     0.645828
# 10000    0.465001
# 10001    0.542448
#            ...
# 9990     0.722046
# 9991     0.477415
# 9992     0.479116
# 9993     0.589634
# 9997     0.571096
# Length: 12328, dtype: float32]
#          HOG002_A549_6H:BRD-K92093830-003-18-3:1.11  \
# NAT2                                       1.151536
# ADA                                        0.365283
# CDH2                                      -0.936901
# AKT3                                      -0.133124
# MED6                                       0.416201
# ...                                             ...
# SLC12A6                                    0.712022
# PTBP3                                     -1.135878
# ...

# %%
# by plate

control_3_a549['avg_control_values'].hist()
plt.title("Average Level 5 Gene Expression Values, A549, DMSO")
plt.xlabel("Average Level 5 Gene Expression Values")
plt.ylabel("Frequency (out of 12328)")
# Out:
# Text(0, 0.5, 'Frequency (out of 12328)')

# %%
BRCA_sample_siginfo['cmap_name'].value_counts()
# Out:
# doxorubicin     665
# paclitaxel      523
# epirubicin      430
# docetaxel       337
# capecitabine    195
# Name: cmap_name, dtype: int64

# %%
control_3_a549['avg_control_values']

# %%
# getting just controls

all_siginfo_controls = siginfo[siginfo['pert_type'] == 'ctl_vehicle']
all_siginfo_controls_a549 = all_siginfo_controls[all_siginfo_controls['cell_mfc_name'] == 'A549']
all_siginfo_controls_a549_pert_6 = all_siginfo_controls_a549[all_siginfo_controls_a549['pert_time'] == 6.0]
all_siginfo_controls_a549_pert_6
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 715          f1b10           NaN        NaN            NaN        NaN
# 1355         f1b10           NaN        NaN            NaN        NaN
# 1356         f1b10           NaN        NaN            NaN        NaN
# 1367           b11           NaN        NaN            NaN        NaN
# 1475         f1b10           NaN        NaN            NaN        NaN
# ...            ...           ...        ...            ...        ...
# 1123041       f2b6           NaN        NaN            NaN        NaN
# 1124152       f2b6           NaN        NaN            NaN        NaN
# 1124250       f2b6           NaN        NaN            NaN        NaN
# 1124251       f2b6           NaN        NaN            NaN        NaN
# 1124672       f2b6           NaN        NaN            NaN        NaN
#
#         pert_itime  pert_time pert_time_unit cell_mfc_name pert_mfc_id  \
# ...

# %%
all_siginfo_controls_a549_pert_6[all_siginfo_controls_a549_pert_6["is_exemplar_sig"] == 0]
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 715          f1b10           NaN        NaN            NaN        NaN
# 1355         f1b10           NaN        NaN            NaN        NaN
# 1356         f1b10           NaN        NaN            NaN        NaN
# 1367           b11           NaN        NaN            NaN        NaN
# 1475         f1b10           NaN        NaN            NaN        NaN
# ...            ...           ...        ...            ...        ...
# 1123041       f2b6           NaN        NaN            NaN        NaN
# 1124152       f2b6           NaN        NaN            NaN        NaN
# 1124250       f2b6           NaN        NaN            NaN        NaN
# 1124251       f2b6           NaN        NaN            NaN        NaN
# 1124672       f2b6           NaN        NaN            NaN        NaN
#
#         pert_itime  pert_time pert_time_unit cell_mfc_name pert_mfc_id  \
# ...

# %%
control_df_5[control_df_5.columns[control_df_5.columns.str.contains("A549_6H")]]
# Out:
# cid    ASG003_A549_6H:A03  ASG003_A549_6H:B03  ASG003_A549_6H:G13  \
# rid
# 10               1.592256           -0.494946            0.619777
# 100             -1.635160           -0.002609           -1.420524
# 1000             0.213324            0.298587            0.247458
# 10000            0.002123            0.177357            0.000000
# 10001            0.397071           -0.307330            0.057793
# ...                   ...                 ...                 ...
# 9990            -0.104077            0.101145            0.275791
# 9991            -1.197079            0.164586           -0.898400
# 9992             0.441157           -0.424390            1.033157
# 9993             1.202459            0.174381            0.107845
# 9997            -0.078483            0.446129           -0.594478
#
# cid    ASG003_A549_6H:G14  ASG003_A549_6H:G15  ASG003_A549_6H:G16  \
# rid
# 10              -0.355031           -0.133550           -0.194738
# ...

# %%
all_siginfo_controls_a549_pert_6['pert_mfc_id'].value_counts()
# Out:
# DMSO    594
# Name: pert_mfc_id, dtype: int64

# %%
sig_id_control = []
for i in all_siginfo_controls_a549_pert_6['sig_id']:
    sig_id_control.append(i)

# %%
all_control_df_a549_pert_6  = control_df_5[sig_id_control]
all_control_df_a549_pert_6
# Out:
# cid    HOG003_A549_6H:C01  HOG002_A549_6H:P13  HOG002_A549_6H:B13  \
# rid
# 10                 1.6019             -0.2308              0.5906
# 100                0.2167              0.7563              0.4532
# 1000               0.6233              0.4303             -0.7199
# 10000             -0.1259             -0.0087              0.8480
# 10001             -1.0661              0.7798             -0.7695
# ...                   ...                 ...                 ...
# 9990              -1.2530             -1.0260             -0.8276
# 9991               0.3234             -0.7653              0.1175
# 9992              -0.0132             -0.6825             -0.4547
# 9993              -2.4687              0.8370             -0.7555
# 9997              -0.1449              0.7856              0.0799
#
# cid    HOG001_A549_6H:O24  HOG002_A549_6H:E01  HOG003_A549_6H:M24  \
# rid
# 10               -0.02550             0.61155             0.11395
# ...

# %%
all_control_df_a549_pert_6.iloc[:,0:4].hist(bins = 100, range = [-5,5])
#plt.xlim([-5,5])
# Out:
# array([[<Axes: title={'center': 'HOG003_A549_6H:C01'}>,
#         <Axes: title={'center': 'HOG002_A549_6H:P13'}>],
#        [<Axes: title={'center': 'HOG002_A549_6H:B13'}>,
#         <Axes: title={'center': 'HOG001_A549_6H:O24'}>]], dtype=object)

# %%
siginfo_dox_A549 = BRCA_sample_siginfo_dox[BRCA_sample_siginfo_dox['cell_mfc_name'] == 'A549']
siginfo_dox_A549
# Out:
#      bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose pert_itime  \
# 0         f1b10         1.110   1.110000             uM    1.11 uM        6 h
# 7         f1b10         0.040   0.041200             uM    0.04 uM       24 h
# 13        f1b10         3.330   3.330000             uM    3.33 uM        6 h
# 32        f1b10         0.125   0.123400             uM   0.125 uM        6 h
# 46        f1b10         0.370   0.370400             uM    0.37 uM        6 h
# 55        f1b10         0.010   0.013000             uM    0.01 uM        6 h
# 66        f1b10         0.002   0.001500             uM   0.002 uM        6 h
# 89        f1b10         0.002   0.001500             uM   0.002 uM       24 h
# 109       f1b10         1.110   1.110000             uM    1.11 uM       24 h
# 113       f1b10         0.125   0.123400             uM   0.125 uM       24 h
# 115       f1b10         0.040   0.041200             uM    0.04 uM        6 h
# ...

# %%
siginfo_dox_A549_10 = siginfo_dox_A549[siginfo_dox_A549['pert_dose'] == 10.000000]
siginfo_dox_A549_10
# Out:
#      bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose pert_itime  \
# 128       f1b10          10.0       10.0             uM      10 uM        6 h
# 188       f1b10          10.0       10.0             uM      10 uM       24 h
# 485          b3          10.0       10.0             uM      10 uM       24 h
# 530        f1b6          10.0       10.0             uM      10 uM       24 h
# 552        f1b3          10.0       10.0             uM      10 uM        6 h
# 561        f1b3          10.0       10.0             uM      10 uM        6 h
# 565        f1b6          10.0       10.0             uM      10 uM       24 h
# 593        f1b6          10.0       10.0             uM      10 uM       24 h
# 614        f2b5          10.0       10.0             uM      10 uM        6 h
# 647          b3          10.0       10.0             uM      10 uM        6 h
# 1842        b29          10.0       10.0             uM      10 uM       24 h
# ...

# %%
siginfo_dox_A549_10_3 = siginfo_dox_A549_10[siginfo_dox_A549['nsample'] == 3]
siginfo_dox_A549_10_3
# Out:
# /tmp/ipykernel_3588/1436896540.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   siginfo_dox_A549_10_3 = siginfo_dox_A549_10[siginfo_dox_A549['nsample'] == 3]
#      bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose pert_itime  \
# 128       f1b10          10.0       10.0             uM      10 uM        6 h
# 552        f1b3          10.0       10.0             uM      10 uM        6 h
# 561        f1b3          10.0       10.0             uM      10 uM        6 h
# 593        f1b6          10.0       10.0             uM      10 uM       24 h
# 647          b3          10.0       10.0             uM      10 uM        6 h
# 1993        b13          10.0       10.0             uM      10 uM       24 h
#
#       pert_time pert_time_unit cell_mfc_name    pert_mfc_id  nsample  cc_q75  \
# 128         6.0              h          A549  BRD-K92093830        3    0.67
# ...

# %%
sig_id_cp = []
for i in siginfo_dox_A549_10_3['sig_id']:
    sig_id_cp.append(i)
cp_dox_A549_10_3  = first_cp[sig_id_cp]
cp_dox_A549_10_3
# Out:
#          HOG002_A549_6H:BRD-K92093830-003-18-3:10  \
# NAT2                                     1.121171
# ADA                                      0.984488
# CDH2                                     0.116930
# AKT3                                     0.101162
# MED6                                    -1.722927
# ...                                           ...
# SLC12A6                                  1.219703
# PTBP3                                    0.948744
# KCNE2                                   -0.307560
# DGCR2                                    1.019474
# SCO2                                    -1.286866
#
#          CPC018_A549_6H:BRD-A52530684-001-01-1:10  \
# NAT2                                     1.986614
# ADA                                      1.587582
# CDH2                                    -0.336435
# AKT3                                     0.357575
# MED6                                    -1.166071
# ...                                           ...
# ...

# %%
cp_dox_A549_10_3.iloc[:,:4].hist(bins = 100, range = [-5,5])
print(cp_dox_A549_10_3.iloc[:,:4].mean())
cp_dox_A549_10_3.iloc[:,:4].std()
# Out:
# HOG002_A549_6H:BRD-K92093830-003-18-3:10     0.412525
# CPC018_A549_6H:BRD-A52530684-001-01-1:10     0.258751
# CPC011_A549_6H:BRD-K92093830-003-23-3:10     0.175442
# CPC011_A549_24H:BRD-K92093830-003-23-3:10    1.018099
# dtype: float64
# HOG002_A549_6H:BRD-K92093830-003-18-3:10     1.601022
# CPC018_A549_6H:BRD-A52530684-001-01-1:10     1.282104
# CPC011_A549_6H:BRD-K92093830-003-23-3:10     1.444019
# CPC011_A549_24H:BRD-K92093830-003-23-3:10    2.410598
# dtype: float64

# %%
all_control_df_a549_pert_6.iloc[:,589:-1].hist(bins = 100, range = [-5,5])
print(all_control_df_a549_pert_6.iloc[:,589:-1].mean())
all_control_df_a549_pert_6.iloc[:,589:-1].std()
# Out:
# cid
# PCLB001_A549_6H:D02   -0.000540
# PCLB001_A549_6H:C09   -0.065390
# PCLB001_A549_6H:C10   -0.001619
# PCLB001_A549_6H:O06    0.036464
# dtype: float32
# cid
# PCLB001_A549_6H:D02    0.569591
# PCLB001_A549_6H:C09    0.620699
# PCLB001_A549_6H:C10    0.620382
# PCLB001_A549_6H:O06    0.595078
# dtype: float32

# %%
# choose experiment I like, exemplar
# all control average, z-score avferage for gene
# control_z_score val vs experiment i like
# scatter plot

# for specific experiment, z-score the z-score
# then plot the distribution again

# %%
all_control_df_a549_pert_6_mean = all_control_df_a549_pert_6.mean(axis = 1)
all_control_df_a549_pert_6_mean # means for each gene calculated across all control experiments
# Out:
# rid
# 10      -0.086779
# 100     -0.022977
# 1000     0.006454
# 10000    0.762849
# 10001    0.062841
#            ...
# 9990     0.069273
# 9991    -0.006420
# 9992     0.081812
# 9993     0.060258
# 9997    -0.076472
# Length: 12328, dtype: float32

# %%
cp_dox_A549_10_3["CPC005_A549_6H:BRD-A76941896-003-02-0:10"]
# Out:
# NAT2       2.906323
# ADA       -1.960055
# CDH2       1.111061
# AKT3       2.696264
# MED6      -3.028999
#              ...
# SLC12A6    1.935311
# PTBP3     -0.608360
# KCNE2      4.075553
# DGCR2      4.207691
# SCO2      -2.250594
# Name: CPC005_A549_6H:BRD-A76941896-003-02-0:10, Length: 12328, dtype: float64

# %%
plt.scatter(all_control_df_a549_pert_6_mean, cp_dox_A549_10_3["CPC005_A549_6H:BRD-A76941896-003-02-0:10"])
plt.xlabel("mean_control_genes")
plt.ylabel("cp_dox_A549_10_3_is_exemplar")
# Out:
# Text(0, 0.5, 'cp_dox_A549_10_3_is_exemplar')

# %%
plt.scatter(cp_dox_A549_10_3["CPC005_A549_6H:BRD-A76941896-003-02-0:10"], cp_dox_A549_10_3["CPC018_A549_6H:BRD-A52530684-001-01-1:10"])
print(np.corrcoef(cp_dox_A549_10_3["CPC005_A549_6H:BRD-A76941896-003-02-0:10"], cp_dox_A549_10_3["CPC018_A549_6H:BRD-A52530684-001-01-1:10"]))
plt.title("Two Exemplar Dox Experiments")
plt.xlabel("CPC005_A549_6H:BRD-A76941896-003-02-0:10")
plt.ylabel("CPC018_A549_6H:BRD-A52530684-001-01-1:10")
# Out:
# [[1.         0.69078696]
#  [0.69078696 1.        ]]
# Text(0, 0.5, 'CPC018_A549_6H:BRD-A52530684-001-01-1:10')

# %%
plt.scatter(all_control_df_a549_pert_6["HOG002_A549_6H:D01"], all_control_df_a549_pert_6["HOG003_A549_6H:M01"])
print(np.corrcoef(all_control_df_a549_pert_6["HOG002_A549_6H:D01"], all_control_df_a549_pert_6["HOG003_A549_6H:M01"]))
plt.title("Two ishiq = 1 Control Experiments")
# plt.xlabel("CPC005_A549_6H:BRD-A76941896-003-02-0:10")
# plt.ylabel("CPC018_A549_6H:BRD-A52530684-001-01-1:10")
# Out:
# [[1.         0.36006087]
#  [0.36006087 1.        ]]
# Text(0.5, 1.0, 'Two ishiq = 1 Control Experiments')

# %%
plt.scatter(all_control_df_a549_pert_6["PCLB001_A549_6H:D02"], all_control_df_a549_pert_6["PCLB001_A549_6H:C09"])
print(np.corrcoef(all_control_df_a549_pert_6["PCLB001_A549_6H:D02"], all_control_df_a549_pert_6["PCLB001_A549_6H:C09"]))
plt.title("Two ishiq = 0 Control Experiments")
# plt.xlabel("CPC005_A549_6H:BRD-A76941896-003-02-0:10")
# plt.ylabel("CPC018_A549_6H:BRD-A52530684-001-01-1:10")
# Out:
# [[1.         0.08775134]
#  [0.08775134 1.        ]]
# Text(0.5, 1.0, 'Two ishiq = 0 Control Experiments')

# %%
plt.scatter(cp_dox_A549_10_3["CPC005_A549_6H:BRD-A76941896-003-02-0:10"], all_control_df_a549_pert_6["HOG002_A549_6H:D01"])
print(np.corrcoef(cp_dox_A549_10_3["CPC005_A549_6H:BRD-A76941896-003-02-0:10"], all_control_df_a549_pert_6["HOG002_A549_6H:D01"]))
plt.title("Exemplar Experiment (is_hiq = 1) vs ishiq = 1 control")
# Out:
# [[1.         0.00843088]
#  [0.00843088 1.        ]]
# Text(0.5, 1.0, 'Exemplar Experiment vs ishiq = 1 control')

# %%
plt.scatter(all_control_df_a549_pert_6["RAD001_A549_6H:M01"], all_control_df_a549_pert_6["HOG003_A549_6H:M01"])
print(np.corrcoef(all_control_df_a549_pert_6["RAD001_A549_6H:M01"], all_control_df_a549_pert_6["HOG003_A549_6H:M01"]))
plt.title("Two ishiq = 1 Control Experiments ( 2 vs 3 replicates ")
# Out:
# [[ 1.        -0.0490692]
#  [-0.0490692  1.       ]]
# Text(0.5, 1.0, 'Two ishiq = 1 Control Experiments ( 2 vs 3 replicates ')

# %%
plt.scatter(all_control_df_a549_pert_6["CPC007_A549_6H:H01"], all_control_df_a549_pert_6["HOG003_A549_6H:M01"])
print(np.corrcoef(all_control_df_a549_pert_6["CPC007_A549_6H:H01"], all_control_df_a549_pert_6["HOG003_A549_6H:M01"]))
plt.title("Two ishiq = 1 Control Experiments ( 3 vs 3 replicates")
# Out:
# [[1.         0.15194491]
#  [0.15194491 1.        ]]
# Text(0.5, 1.0, 'Two ishiq = 1 Control Experiments ( 3 vs 3 replicates')

# %%
siginfo_dox_A549_10_3
# Out:
#      bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose pert_itime  \
# 128       f1b10          10.0       10.0             uM      10 uM        6 h
# 552        f1b3          10.0       10.0             uM      10 uM        6 h
# 561        f1b3          10.0       10.0             uM      10 uM        6 h
# 593        f1b6          10.0       10.0             uM      10 uM       24 h
# 647          b3          10.0       10.0             uM      10 uM        6 h
# 1993        b13          10.0       10.0             uM      10 uM       24 h
#
#       pert_time pert_time_unit cell_mfc_name    pert_mfc_id  nsample  cc_q75  \
# 128         6.0              h          A549  BRD-K92093830        3    0.67
# 552         6.0              h          A549  BRD-A52530684        3    0.67
# 561         6.0              h          A549  BRD-K92093830        3    0.67
# 593        24.0              h          A549  BRD-K92093830        3    0.78
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[248], line 1
# ----> 1 all_control_df_a549_siginfo_6
#
# NameError: name 'all_control_df_a549_siginfo_6' is not defined

# %%
all_siginfo_controls_a549_pert_6_quality =  all_siginfo_controls_a549_pert_6[all_siginfo_controls_a549_pert_6['is_hiq'] == 1]

all_siginfo_controls_a549_pert_6_quality
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 3041          f1b5           NaN        NaN            NaN        NaN
# 28701        f1b10           NaN        NaN            NaN        NaN
# 42226        f1b10           NaN        NaN            NaN        NaN
# 48950        f1b10           NaN        NaN            NaN        NaN
# 63280          b11           NaN        NaN            NaN        NaN
# 69993          b22           NaN        NaN            NaN        NaN
# 108579         b41           NaN        NaN            NaN        NaN
# 166413          b3           NaN        NaN            NaN        NaN
# 168620        f1b3           NaN        NaN            NaN        NaN
# 171933        f1b3           NaN        NaN            NaN        NaN
# 175240          b3           NaN        NaN            NaN        NaN
# 176336        f1b4           NaN        NaN            NaN        NaN
# ...

# %%
all_siginfo_controls_a549_pert_6
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 715          f1b10           NaN        NaN            NaN        NaN
# 1355         f1b10           NaN        NaN            NaN        NaN
# 1356         f1b10           NaN        NaN            NaN        NaN
# 1367           b11           NaN        NaN            NaN        NaN
# 1475         f1b10           NaN        NaN            NaN        NaN
# ...            ...           ...        ...            ...        ...
# 1123041       f2b6           NaN        NaN            NaN        NaN
# 1124152       f2b6           NaN        NaN            NaN        NaN
# 1124250       f2b6           NaN        NaN            NaN        NaN
# 1124251       f2b6           NaN        NaN            NaN        NaN
# 1124672       f2b6           NaN        NaN            NaN        NaN
#
#         pert_itime  pert_time pert_time_unit cell_mfc_name pert_mfc_id  \
# ...

# %%
all_control_df_a549_pert_6
# Out:
# cid    HOG003_A549_6H:C01  HOG002_A549_6H:P13  HOG002_A549_6H:B13  \
# rid
# 10                 1.6019             -0.2308              0.5906
# 100                0.2167              0.7563              0.4532
# 1000               0.6233              0.4303             -0.7199
# 10000             -0.1259             -0.0087              0.8480
# 10001             -1.0661              0.7798             -0.7695
# ...                   ...                 ...                 ...
# 9990              -1.2530             -1.0260             -0.8276
# 9991               0.3234             -0.7653              0.1175
# 9992              -0.0132             -0.6825             -0.4547
# 9993              -2.4687              0.8370             -0.7555
# 9997              -0.1449              0.7856              0.0799
#
# cid    HOG001_A549_6H:O24  HOG002_A549_6H:E01  HOG003_A549_6H:M24  \
# rid
# 10               -0.02550             0.61155             0.11395
# ...

# %%
# now need to z-score the z-scores. do this
all_control_df_a549_pert_6_std = all_control_df_a549_pert_6.std(axis = 1)

# %%
all_control_df_a549_pert_6_mean_list = list(all_control_df_a549_pert_6_mean)
all_control_df_a549_pert_6_std_list = list(all_control_df_a549_pert_6_std)
cp_dox_A549_10_3_list = list(cp_dox_A549_10_3["CPC005_A549_6H:BRD-A76941896-003-02-0:10"])

# %%
new_z_scores = []
for i in range(len(cp_dox_A549_10_3_list)):
    new_z_scores.append(  ( (cp_dox_A549_10_3_list[i] - all_control_df_a549_pert_6_mean_list[i]) /  all_control_df_a549_pert_6_std_list[i] ) )

# %%
new_z_scores = pd.DataFrame(new_z_scores)
new_z_scores.hist(bins = 100)
plt.xlabel("z-scores of z-scores")
# Out:
# Text(0.5, 0, 'z-scores of z-scores')

# %%
gene_information = pd.read_csv("/home/ndjed/Programs/VSCode/LINCS_Project/geneinfo_beta.txt", sep = '\t')

# %%
gene_information.iloc[:,2]
# Out:
# 0                    NaN
# 1        ENSG00000229807
# 2        ENSG00000224975
# 3        ENSG00000226777
# 4        ENSG00000082929
#               ...
# 12322    ENSG00000265354
# 12323    ENSG00000204946
# 12324    ENSG00000204520
# 12325    ENSG00000221870
# 12326    ENSG00000155640
# Name: ENSG00000221819, Length: 12327, dtype: object

# %%
first_cp
# Out:
#          HOG002_A549_6H:BRD-K92093830-003-18-3:1.11  \
# NAT2                                       1.151536
# ADA                                        0.365283
# CDH2                                      -0.936901
# AKT3                                      -0.133124
# MED6                                       0.416201
# ...                                             ...
# SLC12A6                                    0.712022
# PTBP3                                     -1.135878
# KCNE2                                      0.335211
# DGCR2                                      0.289232
# SCO2                                      -0.130264
#
#          HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.1234  \
# NAT2                                         -0.440742
# ADA                                          -0.089785
# CDH2                                         -0.402407
# AKT3                                          0.616265
# MED6                                         -0.668459
# ...

# %%
first_cp.columns[first_cp.columns.str.contains("SUM159PT:")]
# Out:
# Index([], dtype='object')

# %%
siginfo
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 0              b17           NaN      100.0          ug/ml  100 ug/ml
# 1              b15          10.0       10.0             uM      10 uM
# 2              b15           2.5        2.5             uM     2.5 uM
# 3              b18          10.0       10.0             uM      10 uM
# 4              b15          10.0       10.0             uM      10 uM
# ...            ...           ...        ...            ...        ...
# 1201939        b18          10.0       10.0             uM      10 uM
# 1201940        b18          10.0       10.0             uM      10 uM
# 1201941        b19          20.0       20.0             uM      20 uM
# 1201942        b19           4.0        5.0             uM       4 uM
# 1201943        b19          10.0       10.0             uM      10 uM
#
#         pert_itime  pert_time pert_time_unit cell_mfc_name    pert_mfc_id  \
# ...

# %%
siginfo[siginfo["cell_mfc_name"] == "MDA-MB-231"]
# Out:
# Empty DataFrame
# Columns: [bead_batch, nearest_dose, pert_dose, pert_dose_unit, pert_idose, pert_itime, pert_time, pert_time_unit, cell_mfc_name, pert_mfc_id, nsample, cc_q75, ss_ngene, tas, pct_self_rank_q25, wt, median_recall_rank_spearman, median_recall_rank_wtcs_50, median_recall_score_spearman, median_recall_score_wtcs_50, batch_effect_tstat, batch_effect_tstat_pct, is_hiq, qc_pass, pert_id, sig_id, pert_type, cell_iname, det_wells, det_plates, distil_ids, build_name, project_code, cmap_name, is_exemplar_sig, is_ncs_sig, is_null_sig]
# Index: []

# %%
interesting_genes = pd.read_csv("interesting_brca_genes.txt", sep = '\t')

# %%
interesting_genes
# Out:
#   Interesting BRCA genes
# 0                   TP53
# 1                  BRCA1
# 2                  BRCA2
# 3                 PIK3CA
# 4                   HER2
# 5                   ESR1
# 6                   ESR2
# 7                    MYC
# 8                 DCAF13

# %%
first_cp_MCF7 = first_cp[first_cp.columns[first_cp.columns.str.contains("MCF7")]]
first_cp_MCF7
# Out:
#          HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.1234  \
# NAT2                                         -0.440742
# ADA                                          -0.089785
# CDH2                                         -0.402407
# AKT3                                          0.616265
# MED6                                         -0.668459
# ...                                                ...
# SLC12A6                                       0.701270
# PTBP3                                         0.515685
# KCNE2                                        -0.161944
# DGCR2                                         0.350343
# SCO2                                          0.678995
#
#          HOG002_MCF7_6H:BRD-K92093830-003-18-3:0.3704  \
# NAT2                                         0.519634
# ADA                                         -0.009424
# CDH2                                         0.967200
# AKT3                                        -1.291086
# ...

# %%
first_cp_MC57_columns_list = first_cp_MCF7.columns.tolist()
first_cp_MC57_columns_list
# Out:
# ['HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.1234',
#  'HOG002_MCF7_6H:BRD-K92093830-003-18-3:0.3704',
#  'HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.013',
#  'HOG002_MCF7_6H:BRD-K92093830-003-18-3:1.11',
#  'HOG002_MCF7_6H:BRD-K92093830-003-18-3:0.0015',
#  'HOG002_MCF7_6H:BRD-K92093830-003-18-3:0.013',
#  'CPD002_MCF7_6H:BRD-K92093830-003-21-7:10',
#  'HOG002_MCF7_6H:BRD-K92093830-003-18-3:0.1234',
#  'HOG002_MCF7_24H:BRD-K92093830-003-18-3:10',
#  'HOG002_MCF7_6H:BRD-K92093830-003-18-3:0.0045',
#  'HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.0015',
#  'HOG002_MCF7_6H:BRD-K92093830-003-18-3:3.33',
#  'HOG002_MCF7_6H:BRD-K92093830-003-18-3:0.0412',
#  'CPD002_MCF7_24H:BRD-K92093830-003-21-7:10',
#  'HOG002_MCF7_24H:BRD-K92093830-003-18-3:1.11',
#  'HOG002_MCF7_24H:BRD-K92093830-003-18-3:3.33',
#  'HOG002_MCF7_6H:BRD-K92093830-003-18-3:10',
#  'HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.0412',
#  'HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.3704',
# ...

# %%
siginfo_MC57_dox = siginfo[siginfo['sig_id'].isin(first_cp_MC57_columns_list)]
siginfo_MC57_dox
siginfo_MC57_dox['pert_itime'].value_counts()
# matching_rows = df[df['Column1'].isin(value_list)]
# Out:
# 24 h    40
# 6 h     19
# 48 h     3
# Name: pert_itime, dtype: int64

# %%
control_df_5
# Out:
# cid    ABY001_A375_XH:CMAP-000:-666:24  ABY001_A375_XH:CMAP-000:-666:3  \
# rid
# 10                            0.320485                       -0.475566
# 100                          -0.345218                       -0.188009
# 1000                          0.132398                       -0.097883
# 10000                         0.239660                       -0.194304
# 10001                        -0.205412                        0.026935
# ...                                ...                             ...
# 9990                          0.270770                        0.181627
# 9991                         -0.029380                       -0.268213
# 9992                          0.230479                        0.403226
# 9993                          0.181131                       -0.116034
# 9997                         -0.335440                        0.294594
#
# cid    ABY001_A375_XH:DMSO:-666:24  ABY001_A375_XH:DMSO:-666:3  \
# rid
# ...

# %%
filt1 = siginfo['cell_mfc_name'] == 'MCF7' 
filt2 = siginfo['pert_type'] == 'ctl_vehicle' 
filt3 = siginfo['pert_time'] == 24.0
filt4 = siginfo['is_hiq'] == 1
filt5 = siginfo['qc_pass'] == 1

final_filt = filt1 & filt2 & filt3 & filt4 & filt5

control_MC57_ctrl_hiq = siginfo[final_filt]
control_MC57_ctrl_hiq
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 3669           b23           NaN        NaN            NaN        NaN
# 3757           b11           NaN        NaN            NaN        NaN
# 6667           b23           NaN        NaN            NaN        NaN
# 9035           b23           NaN        NaN            NaN        NaN
# 9654            b7           NaN        NaN            NaN        NaN
# ...            ...           ...        ...            ...        ...
# 1180406        b20           NaN        NaN            NaN        NaN
# 1181565        b21           NaN        NaN            NaN        NaN
# 1182695        b21           NaN        NaN            NaN        NaN
# 1183099        b21           NaN        NaN            NaN        NaN
# 1184218        b21           NaN        NaN            NaN        NaN
#
#         pert_itime  pert_time pert_time_unit cell_mfc_name pert_mfc_id  ...  \
# ...

# %%
pd.set_option('display.max_columns', 37)

# %%
control_MC57_ctrl_hiq[control_MC57_ctrl_hiq['cmap_name'] == 'DMSO']
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 3669           b23           NaN        NaN            NaN        NaN
# 3757           b11           NaN        NaN            NaN        NaN
# 6667           b23           NaN        NaN            NaN        NaN
# 9035           b23           NaN        NaN            NaN        NaN
# 9654            b7           NaN        NaN            NaN        NaN
# ...            ...           ...        ...            ...        ...
# 1180406        b20           NaN        NaN            NaN        NaN
# 1181565        b21           NaN        NaN            NaN        NaN
# 1182695        b21           NaN        NaN            NaN        NaN
# 1183099        b21           NaN        NaN            NaN        NaN
# 1184218        b21           NaN        NaN            NaN        NaN
#
#         pert_itime  pert_time pert_time_unit cell_mfc_name pert_mfc_id  \
# ...

# %%
control_MC57_ctrl_hiq.loc[3669, "det_plates"]
# Out:
# 'POL001_MCF7_24H_X1.L2_B23|POL001_MCF7_24H_X2.L2_B23|POL001_MCF7_24H_X3.L2_B23'

# %%
control_MC57_ctrl_hiq_ids = control_MC57_ctrl_hiq['sig_id'].tolist()

control_MC57_ctrl_hiq_vals = control_df_5[control_df_5.columns[control_df_5.columns.isin(control_MC57_ctrl_hiq_ids)]]
control_MC57_ctrl_hiq_vals
# Out:
# cid    ASG002_MCF7_24H:O05  ASG002_MCF7_24H:O06  ASG003_MCF7_24H:A03  \
# rid
# 10               -0.273875            -0.320680             0.233230
# 100               1.216856             0.397236             0.591452
# 1000              0.157880             0.624691             0.475867
# 10000            -0.301010             0.102191             0.115678
# 10001             0.051972            -0.354448            -0.437440
# ...                    ...                  ...                  ...
# 9990             -0.200090             0.622153             0.845421
# 9991              0.918145             0.032726             0.192177
# 9992             -0.722828            -0.278393            -0.770793
# 9993             -0.479199            -0.684705             0.019604
# 9997              0.654926            -0.371883             0.638462
#
# cid    ASG003_MCF7_24H:O01  ASG003_MCF7_24H:O03  ASG003_MCF7_24H:O06  \
# rid
# ...

# %%
#z scoring the controls here, part 2
control_MCF7_mean = control_MC57_ctrl_hiq_vals.mean(axis = 1).tolist()
control_MCF7_std = control_MC57_ctrl_hiq_vals.std(axis = 1).tolist()

# %%
# now I need to choose an interesting experiment
siginfo_MC57_dox_exemplar_sig = siginfo_MC57_dox[siginfo_MC57_dox['is_exemplar_sig'] == 1]
siginfo_MC57_dox_exemplar_sig
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 49448           b6         10.00       10.0             uM      10 uM
# 225681          b3         10.00       10.0             uM      10 uM
# 1060731        b41          1.11        1.0             uM    1.11 uM
# 1118510        b13         10.00       10.0             uM      10 uM
#
#         pert_itime  pert_time pert_time_unit cell_mfc_name  \
# 49448         24 h       24.0              h          MCF7
# 225681         6 h        6.0              h          MCF7
# 1060731       48 h       48.0              h          MCF7
# 1118510       24 h       24.0              h          MCF7
#
#                     pert_mfc_id  nsample  cc_q75  ss_ngene       tas  \
# 49448             BRD-K92093830        3  0.7600       655  0.713441
# 225681   BRD-A76941896-003-02-0        4  0.7188       641  0.686378
# 1060731           BRD-K61468417        5  0.8083       786  0.805987
# ...

# %%
cp_dox_MCF7_24_10_is_exemp_1 = first_cp["CPD002_MCF7_24H:BRD-K92093830-003-21-7:10"]
cp_dox_MCF7_24_10_is_exemp_2 = first_cp["PCLB003_MCF7_24H:BRD-A52530684-003-01-7:10"]

# %%
import matplotlib.pyplot as plt
def graphScatter(x, y, title = ""):
    
    plt.axhline(0, color='black', linestyle='-')
    plt.axvline(0, color='black', linestyle='-')
    plt.scatter(x, y, s= 10, alpha = 0.05)

    corr = np.corrcoef(x, y)[0, 1]
    plt.text(0.75, 0.95, f'Correlation: {corr:.2f}', ha='center', va='top', transform=plt.gca().transAxes)
    m, b = np.polyfit(x, y, deg=1)
    plt.plot(x, m*x + b, color='red')

    plt.text(0.75, 0.85, f'Slope of Line of Best Fit: {m:.2f}', ha='center', va='top', transform=plt.gca().transAxes)
    plt.text(0.75, 0.80, f'y-intercept: {b:.2f}', ha='center', va='top', transform=plt.gca().transAxes)

    plt.scatter(x, y, s= 10, alpha = 0.2, color = 'darkblue')

    x = pd.DataFrame(x)
    y = pd.DataFrame(y)
    plt.xlabel(f"{x.columns}")
    plt.ylabel(f"{y.columns}")

    plt.title(f"{title}")

# %%
graphScatter(cp_dox_MCF7_24_10_is_exemp_1,cp_dox_MCF7_24_10_is_exemp_2, title = "MCF7 cp, dox, 24 hrs, 10 micromils, is exemp")

# %%
# now need to subtract every val in experiment by null mean and divide by std
cp_dox_MCF7_24_10_is_exemp_1_list = cp_dox_MCF7_24_10_is_exemp_1.tolist()



cp_dox_MCF7_24_10_is_exemp_1_list_z_scores = []
for i in range(len(cp_dox_MCF7_24_10_is_exemp_1_list)):
    cp_dox_MCF7_24_10_is_exemp_1_list_z_scores.append(  ( (cp_dox_MCF7_24_10_is_exemp_1_list[i] - control_MCF7_mean [i]) /  control_MCF7_std[i] ) )

# %%
cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df = pd.DataFrame(cp_dox_MCF7_24_10_is_exemp_1_list_z_scores)
cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df.hist(bins = 100, color = "darkblue")
plt.xlabel(f"{cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df.columns}")
# Out:
# Text(0.5, 0, 'RangeIndex(start=0, stop=1, step=1)')

# %%
cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df.index = first_cp.index
cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df
# Out:
#                 0
# NAT2     2.833743
# ADA      2.847193
# CDH2    -0.919626
# AKT3     4.656516
# MED6    -4.406494
# ...           ...
# SLC12A6  2.481074
# PTBP3   -0.486291
# KCNE2    4.105985
# DGCR2    3.206921
# SCO2    -1.122860
#
# [12328 rows x 1 columns]

# %%
new_df = pd.DataFrame()
new_df.index = cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df.index
new_df['Module Inclusion'] = 0
print(new_df)

for i in new_df.index:
    if i in significant_cp_dox_MCF7_24_10_is_exemp_1['index'].tolist():
        new_df.loc[i, "Module Inclusion"] = 1
# Out:
#          Module Inclusion
# NAT2                    0
# ADA                     0
# CDH2                    0
# AKT3                    0
# MED6                    0
# ...                   ...
# SLC12A6                 0
# PTBP3                   0
# KCNE2                   0
# DGCR2                   0
# SCO2                    0
#
# [12328 rows x 1 columns]

# %%
new_df.value_counts()
# Out:
# Module Inclusion
# 0                   12196
# 1                     132
# dtype: int64

# %%
significant_cp_dox_MCF7_24_10_is_exemp_1 = cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df[cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df.iloc[:,0] > 6]
significant_cp_dox_MCF7_24_10_is_exemp_1.reset_index(inplace=True)

# %%
significant_cp_dox_MCF7_24_10_is_exemp_1
# Out:
#         index         0
# 0        GJC1  6.572109
# 1       CDH13  6.488977
# 2      CALCRL  6.134830
# 3       RAMP2  6.320668
# 4       IKZF1  7.291824
# ..        ...       ...
# 127      CCNH  6.636388
# 128  TMEM183A  6.025834
# 129      LPXN  6.407676
# 130    HS2ST1  6.985093
# 131      CD68  6.962703
#
# [132 rows x 2 columns]

# %%
graphScatter(control_MC57_ctrl_hiq_vals["PBIOA022_MCF7_24H:F08"], control_MC57_ctrl_hiq_vals["PBIOA016_MCF7_24H:J14"], title= "MC57 controls, dox, 24 hrs, hiq = 1, part 2")

# %%
write_dataframe_to_csv(cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df, "all_z_Scores_Dox_Module_6")

# %%
cp_dox_MCF7_24_10_is_exemp_1_list_z_scores_df.to_csv('all_z_Scores_Dox_Module_6.tsv', sep='\t', index=True)

# %%
new_df.to_csv('all_Genes_Module_Inclusion_Dox_Module_6.tsv', sep='\t', index=True)

# %%
filt1 = siginfo_MC57_dox["pert_itime"] == "24 h"
filt2 = siginfo_MC57_dox['pert_idose'] == "10 uM"

final_filt = filt1 & filt2
siginfo_MC57_dox_10_24 = siginfo_MC57_dox[final_filt]
siginfo_MC57_dox_10_24
# Out:
#         bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 39554          b10          10.0       10.0             uM      10 uM
# 49448           b6          10.0       10.0             uM      10 uM
# 168850          b5          10.0       10.0             uM      10 uM
# 193963          b4          10.0       10.0             uM      10 uM
# 249257          b5          10.0       10.0             uM      10 uM
# 836434         b25          10.0       10.0             uM      10 uM
# 1062842        b41          10.0       10.0             uM      10 uM
# 1118510        b13          10.0       10.0             uM      10 uM
# 1149236        b21          10.0       10.0             uM      10 uM
#
#         pert_itime  pert_time pert_time_unit cell_mfc_name    pert_mfc_id  \
# 39554         24 h       24.0              h          MCF7  BRD-K92093830
# 49448         24 h       24.0              h          MCF7  BRD-K92093830
# ...

# %%
graphScatter(first_cp["LKCP002_MCF7_24H:I22"], first_cp["REP.A026_MCF7_24H:L19"], "cp_mcf7_dox_10_24")

# %%
graphScatter(first_cp["PBIOA018_MCF7_24H:O07"], control_MC57_ctrl_hiq_vals["PBIOA022_MCF7_24H:F08"],"cp_is_hiq_vs_is_hiq_control")

# %%
# need to look into plates


compound_df_5
# Out:
# cid    ABY001_A375_XH:BRD-A61304759:0.625:24  \
# rid
# 10                                  -0.02435
# 100                                  0.70715
# 1000                                -1.53065
# 10000                               -0.69105
# 10001                                0.79380
# ...                                      ...
# 9990                                 1.08165
# 9991                                 1.47585
# 9992                                -0.32150
# 9993                                -0.18240
# 9997                                -0.07220
#
# cid    ABY001_A375_XH:BRD-A61304759:0.625:3  \
# rid
# 10                                 0.296080
# 100                               -0.855923
# 1000                              -0.976824
# 10000                             -2.368536
# 10001                              0.836673
# ...                                     ...
# 9990                               0.704205
# 9991                               0.752289
# ...

# %%
siginfo_plate_control_test = siginfo[siginfo['det_plates'] == 'POL001_MCF7_24H_X1.L2_B23|POL001_MCF7_24H_X2.L2_B23|POL001_MCF7_24H_X3.L2_B23']
siginfo_plate_control_test
# Out:
#       bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  \
# 237          b23         10.00  10.000000             uM      10 uM
# 238          b23          0.37   0.370370             uM    0.37 uM
# 239          b23          0.37   0.370370             uM    0.37 uM
# 395          b23          1.11   1.111110             uM    1.11 uM
# 396          b23         10.00  10.000000             uM      10 uM
# ...          ...           ...        ...            ...        ...
# 74857        b23          1.25   1.233330             uM    1.25 uM
# 75022        b23          1.11   1.111110             uM    1.11 uM
# 75023        b23          0.37   0.370370             uM    0.37 uM
# 75024        b23          0.04   0.041152             uM    0.04 uM
# 75025        b23          0.04   0.041152             uM    0.04 uM
#
#       pert_itime  pert_time pert_time_unit cell_mfc_name    pert_mfc_id  \
# 237         24 h       24.0              h          MCF7  BRD-K55591206
# ...

# %%
siginfo_plate_control_test['cmap_name'].value_counts()
# Out:
# DMSO               25
# BRD-K97808269      11
# BRD-K55591206       6
# BRD-K83354763       6
# isosilychristin     6
# LDN-193189          6
# daunorubicin        6
# resveratrol         6
# BRD-K69179556       6
# BRD-K86574132       6
# taxifolin           6
# alvocidib           6
# WYE-125132          6
# tyrphostin          6
# BRD-A08789708       6
# silybin-b           6
# metformin           6
# thapsigargin        6
# troglitazone        6
# narciclasine        6
# BMS-387032          6
# TPCA-1              6
# acadesine           6
# brazilin            6
# sirolimus           6
# BRD-K93937110       6
# BRD-A41316391       6
# mitoxantrone        6
# rotenone            6
# oligomycin-a        6
# curcumin            6
# brefeldin-a         6
# silibinin           6
# quercetin           6
# isosilybin-b        6
# prostratin          6
# PD-198306           6
# GSK-2126458         6
# CD-1530             6
# arbidol             6
# silydianin          6
# ...

# %%
siginfo_rna_plate_control = instinfo[instinfo['rna_plate'] == 'HOG002_MCF7_24H_X1']
siginfo_rna_plate_control['cmap_name'].value_counts()
# Out:
# DMSO              34
# tanespimycin       9
# phenanthridone     9
# daunorubicin       9
# mitoxantrone       9
# SID-26681509       9
# BRD-K05649647      9
# BRD-K68202742      9
# NVP-BEZ235         9
# LY-294002          9
# doxorubicin        9
# DL-PDMP            9
# importazole        9
# NVP-AUY922         9
# estradiol          9
# CD-437             9
# COT-10b            9
# phloretin          9
# SKI-II             9
# AG-14361           9
# niclosamide        9
# gemcitabine        9
# sirolimus          9
# BRD-K28296557      9
# vorinostat         9
# BRD-K76674262      9
# XAV-939            9
# geldanamycin       9
# BMS-536924         9
# teniposide         9
# wortmannin         8
# withaferin-a       8
# tretinoin          7
# Name: cmap_name, dtype: int64

# %%
siginfo_rna_plate_control[siginfo_rna_plate_control['cmap_name'] == 'DMSO']
dmso_list_cols = siginfo_rna_plate_control['sample_id'].tolist()

# control_MC57_ctrl_hiq_vals = control_df_5[control_df_5.columns[control_df_5.columns.isin(control_MC57_ctrl_hiq_ids)]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [10, 100, 1000, 10000, 10001, 10003, 10004, 10005, 10006, 10007, 10009, 100093698, 1001, 10010, 100126791, 100128640, 100129250, 100129271, 100129460, 100129482, 10013, 100130331, 100130958, 100131755, 100131825, 100132341, 100132406, 100132476, 100132923, 100134713, 100137047, 10014, 10015, 10016, 10017, 10018, 10019, 1002, 10020, 10021, 10022, 10023, 10024, 10025, 10026, 100272228, 100287932, 100288413, 100289678, 1003, 10036, 10038, 10039, 1004, 10040, 10042, 10043, 10044, 10045, 10046, 10047, 10048, 10049, 100499177, 1005, 10050, 100506469, 100507424, 100507436, 10051, 10052, 10053, 10054, 10055, 10057, 10058, 10059, 1006, 10060, 10061, 10062, 10063, 10066, 10067, 10068, 10069, 1007, 10072, 10073, 10075, 10076, 10077, 10078, 10079, 1008, 10083, 10084, 10085, 10086, 10087, ...]
#
# [12328 rows x 0 columns]

# %%
first_cp
# Out:
#          HOG002_A549_6H:BRD-K92093830-003-18-3:1.11  \
# NAT2                                       1.151536
# ADA                                        0.365283
# CDH2                                      -0.936901
# AKT3                                      -0.133124
# MED6                                       0.416201
# ...                                             ...
# SLC12A6                                    0.712022
# PTBP3                                     -1.135878
# KCNE2                                      0.335211
# DGCR2                                      0.289232
# SCO2                                      -0.130264
#
#          HOG002_MCF7_24H:BRD-K92093830-003-18-3:0.1234  \
# NAT2                                         -0.440742
# ADA                                          -0.089785
# CDH2                                         -0.402407
# AKT3                                          0.616265
# MED6                                         -0.668459
# ...

# %%
siginfo[siginfo['sig_id'] == "HOG002_A549_6H:BRD-K92093830-003-18-3:1.11"]
# Out:
#                                             det_plates
# 169  HOG002_A549_6H_X1_F1B10|HOG002_A549_6H_X2_F1B1...

# %%
tcga_gene_data = pd.read_csv("/home/ndjed/Programs/VSCode/LINCS_Project/data_mrna_seq_v2_rsem.txt", sep = '\t')

# %%
tcga_gene_data
# Out:
#       Hugo_Symbol  Entrez_Gene_Id  TCGA-3C-AAAU-01  TCGA-3C-AALI-01  \
# 0             NaN       100130426           0.0000           0.0000
# 1             NaN       100133144          16.3644           9.2659
# 2        UBE2Q2P2       100134869          12.9316          17.3790
# 3         HMGB1P1           10357          52.1503          69.7553
# 4             NaN           10431         408.0760         563.8930
# ...           ...             ...              ...              ...
# 20526      ZYG11A          440590         258.4940         198.4770
# 20527      ZYG11B           79699        1208.3700         603.5890
# 20528         ZYX            7791        3507.2500        5504.6200
# 20529       ZZEF1           23140        1894.9300        1318.6500
# 20530        ZZZ3           26009        1180.4600         406.7430
#
#        TCGA-3C-AALJ-01  TCGA-3C-AALK-01  TCGA-4H-AAAK-01  TCGA-5L-AAT0-01  \
# 0               0.9066           0.0000           0.0000           0.0000
# ...

# %%
gene_dict
# Out:
# {750: 'GAS8-AS1',
#  6315: 'ATXN8OS',
#  7503: 'XIST',
#  8552: 'INE1',
#  9834: 'FAM30A',
#  10141: 'LINC01587',
#  10255: 'HCG9',
#  10281: 'DSCR4',
#  23434: 'LINC01565',
#  23591: 'FAM215A',
#  26082: 'LINC02249',
#  26138: 'LINC00588',
#  27004: 'TCL6',
#  29018: 'FOXN3-AS2',
#  29075: 'LINC00652',
#  51145: 'LOC51145',
#  51214: 'IGF2-AS',
#  51352: 'WT1-AS',
#  55539: 'KCNQ1DN',
#  58483: 'LINC00474',
#  60467: 'BPESC1',
#  64595: 'TTTY15',
#  78998: 'RHPN1-AS1',
#  80069: 'LINC00574',
#  80072: 'HEXA-AS1',
#  80161: 'ASMTL-AS1',
#  81854: 'ZNF205-AS1',
#  114044: 'MCM3AP-AS1',
#  284649: 'SMG7-AS1',
#  284800: 'FAM182A',
#  317648: 'NOP14-AS1',
#  400084: 'LINC00939',
#  730227: 'LINC01136',
#  100093698: 'GS1-600G8.3',
#  100131825: 'CADM3-AS1',
#  100132923: 'FAM66D',
#  100134713: 'NDUFB2-AS1',
#  1057: 'CELP',
#  1556: 'CYP2B7P',
#  1587: 'ADAM3A',
#  1720: 'DHFRP3',
#  2630: 'GBAP1',
#  2974: 'GUCY1B2',
#  3044: 'HBBP1',
#  5301: 'PIN1P1',
#  5369: 'PMCHL1',
# ...

# %%
tcga_gene_data.dropna(axis = 0, inplace = True)

tcga_gene_data.set_index("Hugo_Symbol", inplace = True)

# %%
def write_dataframe_to_csv(dataframe, filename):
    import csv

    dataframe.to_csv(filename, index=False)

# %%
patient_df = pd.DataFrame(tcga_gene_data.index)
patient_df.set_index(tcga_gene_data.index, inplace = True)
patient_df['gene_exp'] = tcga_gene_data['TCGA-3C-AALI-01']

# %%
patient_df
# Out:
#             Hugo_Symbol   gene_exp
# Hugo_Symbol
# UBE2Q2P2       UBE2Q2P2    17.3790
# HMGB1P1         HMGB1P1    69.7553
# RNU12-2P       RNU12-2P     1.0875
# SSX9P             SSX9P     0.5438
# EZHIP             EZHIP   144.1000
# ...                 ...        ...
# ZYG11A           ZYG11A   198.4770
# ZYG11B           ZYG11B   603.5890
# ZYX                 ZYX  5504.6200
# ZZEF1             ZZEF1  1318.6500
# ZZZ3               ZZZ3   406.7430
#
# [20518 rows x 2 columns]

# %%
write_dataframe_to_csv(patient_df, 'sample_patient_gene_exp.csv')
